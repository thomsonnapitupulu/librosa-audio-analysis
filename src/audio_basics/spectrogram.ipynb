# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
y, sr = librosa.load(librosa.example("nutcracker"))

# %% [markdown]
# ## Spectrogram (Time × Frequency)

# %%
S = librosa.stft(y)
S_db = librosa.amplitude_to_db(abs(S))

plt.figure(figsize=(10, 4))
librosa.display.specshow(S_db, sr=sr, x_axis="time", y_axis="hz")
plt.colorbar()
plt.title("Spectrogram")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mel Spectrogram (Perceptual View)

# %%
S_mel = librosa.feature.melspectrogram(y=y, sr=sr)
S_mel_db = librosa.power_to_db(S_mel, ref=np.max)

plt.figure(figsize=(10, 4))
librosa.display.specshow(S_mel_db, sr=sr, x_axis="time", y_axis="mel")
plt.colorbar()
plt.title("Mel Spectrogram")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample Rate Experiment

# %%
y16, sr16 = librosa.load(librosa.example("nutcracker"), sr=16000)
y44, sr44 = librosa.load(librosa.example("nutcracker"), sr=44100)

print(sr16, len(y16))
print(sr44, len(y44))
# Out:
# 16000 1918015
# 44100 5286528
